# %%
# Time and image relation lists
cpu_cpp_read_times = {
    "butterfly.png": 0.0114722,
    "cat.png": 0.0167981,
    "flower.png": 0.0292095,
    "bird.jpg": 0.64678,
    "bridge.jpg": 0.664493,
    "castle.jpg": 0.656488,
    "forest.jpg": 0.262315,
    "island.jpg": 1.02477,
    "rosewater.jpg": 0.392469,
    "lion.jpg": 0.345238
}

cpu_cpp_interpolation_times = {
    "butterfly.png": 0.496754,
    "cat.png": 3.33391,
    "flower.png": 2.92349,
    "bird.jpg": 175.591,
    "bridge.jpg": 165.934,
    "castle.jpg": 131.933,
    "forest.jpg": 55.9397,
    "island.jpg": 233.482,
    "rosewater.jpg": 106.145,
    "lion.jpg": 82.8346
}

cpu_cpp_write_times = {
    "butterfly.png": 0.117052,
    "cat.png": 0.555647,
    "flower.png": 0.662644,
    "bird.jpg": 38.1214,
    "bridge.jpg": 35.7182,
    "castle.jpg": 30.6054,
    "forest.jpg": 14.0091,
    "island.jpg": 45.3479,
    "rosewater.jpg": 20.5377,
    "lion.jpg": 15.3237
}

# %%
# Dictionary for original image dimensions
cpu_cv2_image_dimensions = {
    "../samples/butterfly.png": "256x256",
    "../samples/cat.png": "696x696",
    "../samples/flower.png": "582x730",
    "../samples/bird.jpg": "6165x4108",
    "../samples/bridge.jpg": "6000x4002",
    "../samples/castle.jpg": "5531x3443",
    "../samples/forest.jpg": "7008x4672",
    "../samples/island.jpg": "7108x4744",
    "../samples/lion.jpg": "4252x2835",
    "../samples/rosewater.jpg": "4822x3135"
}

# Dictionary for time to read the image
cpu_cv2_read_times = {
    "../samples/butterfly.png": 0.001000,
    "../samples/cat.png": 0.005998,
    "../samples/flower.png": 0.008999,
    "../samples/bird.jpg": 0.198999,
    "../samples/bridge.jpg": 0.213999,
    "../samples/castle.jpg": 0.227999,
    "../samples/forest.jpg": 0.220377,
    "../samples/island.jpg": 0.326998,
    "../samples/lion.jpg": 0.125997,
    "../samples/rosewater.jpg": 0.118953
}

# Dictionary for time to resize the image
cpu_cv2_resize_times = {
    "../samples/butterfly.png": 0.003000,
    "../samples/cat.png": 0.001003,
    "../samples/flower.png": 0.002001,
    "../samples/bird.jpg": 0.048033,
    "../samples/bridge.jpg": 0.070999,
    "../samples/castle.jpg": 0.058999,
    "../samples/forest.jpg": 0.080060,
    "../samples/island.jpg": 0.094008,
    "../samples/lion.jpg": 0.049063,
    "../samples/rosewater.jpg": 0.038046
}

# Dictionary for time to write the image
cpu_cv2_write_times = {
    "../samples/butterfly.png": 0.009001,
    "../samples/cat.png": 0.034000,
    "../samples/flower.png": 0.044001,
    "../samples/bird.jpg": 2.269258,
    "../samples/bridge.jpg": 2.320020,
    "../samples/castle.jpg": 2.104185,
    "../samples/forest.jpg": 3.492855,
    "../samples/island.jpg": 3.070368,
    "../samples/lion.jpg": 0.911937,
    "../samples/rosewater.jpg": 1.220961
}

# %%
# Dictionary for image details (width, height, BPP)
gpu_image_details = {
    0: {"Width": 256, "Height": 256, "BPP": 3},
    1: {"Width": 696, "Height": 696, "BPP": 4},
    2: {"Width": 582, "Height": 730, "BPP": 4},
    3: {"Width": 6165, "Height": 4108, "BPP": 3},
    4: {"Width": 6000, "Height": 4002, "BPP": 3},
    5: {"Width": 5531, "Height": 3443, "BPP": 3},
    6: {"Width": 7008, "Height": 4672, "BPP": 3},
    7: {"Width": 7108, "Height": 4744, "BPP": 3},
    8: {"Width": 4252, "Height": 2835, "BPP": 3},
    9: {"Width": 4822, "Height": 3135, "BPP": 3}
}

# Dictionary for time taken to interpolate each image
gpu_interpolation_times = {
    0: 8085.44,
    1: 8205.13,
    2: 8311.45,
    3: 14357.8,
    4: 20233.4,
    5: 24807.8,
    6: 32584.2,
    7: 8069.74,
    8: 27454.1,
    9: 30938.6
}

# Dictionary for time taken to copy data back to host for each image
gpu_copy_times = {
    0: 0.289728,
    1: 1.28819,
    2: 1.15731,
    3: 66.1542,
    4: 68.4646,
    5: 47.4362,
    6: 78.8993,
    7: 82.1115,
    8: 30.0574,
    9: 42.3086
}

# Dictionary for time taken to write each image to disk
gpu_write_times = {
    0: 82.9699,
    1: 353.268,
    2: 466.038,
    3: 27001.4,
    4: 25115.1,
    5: 21423.5,
    6: 38110.2,
    7: 31730,
    8: 10020.9,
    9: 14129
}

# %%
import matplotlib.pyplot as plt

cpu_cpp_interpolation_times = {
    "butterfly.png": 0.496754*1000,
    "cat.png": 3.33391*1000,
    "flower.png": 2.92349*1000,
    "bird.jpg": 175.591*1000,
    "bridge.jpg": 165.934*1000,
    "castle.jpg": 131.933*1000,
    "forest.jpg": 55.9397*1000,
    "island.jpg": 233.482*1000,
    "rosewater.jpg": 106.145*1000,
    "lion.jpg": 82.8346*1000
}

# Dictionary for time to resize the image
cpu_cv2_resize_times = {
    "butterfly.png": 0.003000*1000,
    "cat.png": 0.001003*1000,
    "flower.png": 0.002001*1000,
    "bird.jpg": 0.048033*1000,
    "bridge.jpg": 0.070999*1000,
    "castle.jpg": 0.058999*1000,
    "forest.jpg": 0.080060*1000,
    "island.jpg": 0.094008*1000,
    "lion.jpg": 0.049063*1000,
    "rosewater.jpg": 0.038046*1000
}

# Dictionary for time taken to interpolate each image
gpu_interpolation_times = {
    "butterfly.png": 8085.44,
    "cat.png": 8205.13,
    "flower.png": 8311.45,
    "bird.jpg": 14357.8,
    "bridge.jpg": 20233.4,
    "castle.jpg": 24807.8,
    "forest.jpg": 32584.2,
    "island.jpg": 8069.74,
    "rosewater.jpg": 27454.1,
    "lion.jpg": 30938.6
}

# Prepare data for plotting
images = list(cpu_cpp_interpolation_times.keys())
cpu_cpp_times = list(cpu_cpp_interpolation_times.values())
cpu_cv2_times = list(cpu_cv2_resize_times.values())
gpu_times = list(gpu_interpolation_times.values())

x = range(len(images))

# Plotting the data
plt.figure(figsize=(12, 8))

plt.plot(x, cpu_cpp_times, label='CPU CPP Interpolation Times', marker='o')
plt.plot(x, cpu_cv2_times, label='CPU CV2 Resize Times (ms)', marker='o')
plt.plot(x, gpu_times, label='GPU Interpolation Times (ms)', marker='o')

plt.xticks(x, images, rotation='vertical')
plt.xlabel('Images')
plt.ylabel('Time (milliseconds)')
plt.title('Comparison of Interpolation and Resize Times')
plt.legend()
plt.tight_layout()

plt.show()
